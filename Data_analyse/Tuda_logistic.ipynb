# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from os import listdir
from os.path import isfile, join

# %% [markdown]
# # Sequential

# %%
path =  '/hpc/comco/Sarah.M/Tuda_project/results/sequential/logistic/'

onlyfiles = [f for f in listdir(path) if isfile(join(path, f))]
gamma_logistic = [element for element in onlyfiles if 'gamma' in element]
acc_star_logistic = [element for element in onlyfiles if 'accuracy_star' in element]

# %%
for file in acc_star_logistic:
    acc = pd.read_csv(path + file)
    plt.figure()
    plt.plot(acc)
    plt.ylim(0.4, 0.8)
    plt.plot((0,120),(0.5,0.5),'r:')
    plt.title(f'subject {file[-6:-4]}')

# %%
for i, file in enumerate(gamma_logistic):
    acc = pd.read_csv(path + file)
    plt.figure(figsize=(20, 3))
    for trial in range(10):
        plt.subplot(1,10,trial+1)
        plt.plot(acc[trial*120:(trial+1)*120])
        if i== 0:
            plt.title(f'trial #{trial}')
        if trial ==0:
            plt.ylabel(f'subject {file[-6:-4]}')
    #plt.ylim(0.4, 0.8)
    #plt.plot((0,120),(0.5,0.5),'r:')

# %% [markdown]
# # Regression

# %%
path =  '/hpc/comco/Sarah.M/Tuda_project/results/regression/logistic/'

onlyfiles = [f for f in listdir(path) if isfile(join(path, f))]
gamma_logistic= [element for element in onlyfiles if 'gamma' in element]
acc_star_logistic = [element for element in onlyfiles if 'accuracy_star' in element]

# %%
for file in acc_star_logistic:
    acc = pd.read_csv(path + file)
    plt.figure()
    plt.plot(acc)
    plt.ylim(0.4, 0.8)
    plt.plot((0,120),(0.5,0.5),'r:')
    plt.title(f'subject {file[-6:-4]}')

# %%
for i, file in enumerate(gamma_logistic):
    acc = pd.read_csv(path + file)
    plt.figure(figsize=(20, 3))
    for trial in range(10):
        plt.subplot(1,10,trial+1)
        plt.plot(acc[trial*120:(trial+1)*120])
        if i== 0:
            plt.title(f'trial #{trial}')
        if trial ==0:
            plt.ylabel(f'subject {file[-6:-4]}')
    #plt.ylim(0.4, 0.8)
    #plt.plot((0,120),(0.5,0.5),'r:')
